# %%
import random
import datetime

import pandas as pd

# %%
df = pd.read_csv('Faculty_review.csv')

df
# Out:
#                 SRN                    Full Name Course     Faculty  \
# 0     PES1UG20CS682                    Rohan T P   AIWR  Divyashree
# 1     PES1UG20CS690          Shivangouda I Patil   AIWR  Divyashree
# 2    PES1UG20CS330   REDDYGARI SURYA TEJA REDDY    AIWR  Divyashree
# 3    PES1UG20CS687                  Satvikkumar    AIWR  Divyashree
# 4     PES1UG21CS818           Manjula Kamannavar   AIWR  Divyashree
# ..              ...                          ...    ...         ...
# 780  PES1UG20CS707                    SUNIDHI N    IPNP     Surabhi
# 781   PES1UG20CS805                    Dhanush V   IPNP     Surabhi
# 782   PES1UG20EC200    SREERAMYA DHARANI PRAGADA   IPNP     Surabhi
# 783   PES1UG21CS813         Hathi Dev Rajeshbhai   IPNP     Surabhi
# 784   PES1UG21CS824        Neeraj Gopalakrishnan   IPNP     Surabhi
#
#      Well versed with the subject  Explains concepts in an understandable way  \
# ...

# %%
bias_teacher = {}

bias_teacher['AIWRSurabhi'] = 2
bias_teacher['AIWRNage'] = 1
bias_teacher['AIWRBhaskar'] = 1

bias_teacher['BCShruthi'] = 1

bias_teacher['DFGBhaskar'] = -1
bias_teacher['DFGNage'] = 1

bias_teacher['IPNPVenkatesh'] = 2

# %%
for index, row in df.iterrows():
  #combo = (df['Course'],df['Faculty'])
  combo = str(df['Course'] + df['Faculty'])
  rn = random.randint(1,10)
  bias = 0
  if combo in bias_teacher:
    bias = bias_teacher[combo]

  if (rn + bias) in range(1, 11):
    rn = rn + bias

  df.loc[index,'Well versed with the subject'] = rn

  #bias = 0

  rn = random.randint(1,10)
  if combo in bias_teacher:
    bias = bias_teacher[combo]
  if (rn + bias) in range(1, 11):
    rn = rn + bias
  df.loc[index,'Explains concepts in an understandable way'] = rn

  #bias = 0

  rn = random.randint(1,10)
  if combo in bias_teacher:
    bias = bias_teacher[combo]
  if (rn + bias) in range(1, 11):
    rn = rn + bias
  df.loc[index,'Use of presentations'] = rn

  #bias = 0

  rn = random.randint(1,10)
  if combo in bias_teacher:
    bias = bias_teacher[combo]
  if (rn + bias) in range(1, 11):
    rn = rn + bias
  df.loc[index,'Solves doubts willingly'] = rn

  rn = random.randint(1,10)
  if combo in bias_teacher:
    bias = bias_teacher[combo]
  if (rn + bias) in range(1, 11):
    rn = rn + bias
  df.loc[index,'Provides support for students going above and beyond'] = rn

# %%
df
# Out:
#                 SRN                    Full Name Course     Faculty  \
# 0     PES1UG20CS682                    Rohan T P   AIWR  Divyashree
# 1     PES1UG20CS690          Shivangouda I Patil   AIWR  Divyashree
# 2    PES1UG20CS330   REDDYGARI SURYA TEJA REDDY    AIWR  Divyashree
# 3    PES1UG20CS687                  Satvikkumar    AIWR  Divyashree
# 4     PES1UG21CS818           Manjula Kamannavar   AIWR  Divyashree
# ..              ...                          ...    ...         ...
# 780  PES1UG20CS707                    SUNIDHI N    IPNP     Surabhi
# 781   PES1UG20CS805                    Dhanush V   IPNP     Surabhi
# 782   PES1UG20EC200    SREERAMYA DHARANI PRAGADA   IPNP     Surabhi
# 783   PES1UG21CS813         Hathi Dev Rajeshbhai   IPNP     Surabhi
# 784   PES1UG21CS824        Neeraj Gopalakrishnan   IPNP     Surabhi
#
#      Well versed with the subject  Explains concepts in an understandable way  \
# ...

# %%
bias_course = {}

bias_course['AIWR'] = 2
bias_course['BC'] = 2
bias_course['GP'] = -1

# %%
for index, row in df.iterrows():
  #combo = (df['Course'],df['Faculty'])
  combo = str(df['Course'])
  rn = random.randint(1,10)
  bias = 0
  if combo in bias_course:
    bias = bias_course[combo]

  if (rn + bias) in range(1, 11):
    rn = rn + bias

  df.loc[index,'Degree of difficulty of assignments'] = rn

  rn = random.randint(1,10)
  if (rn + bias) in range(1, 11):
    rn = rn + bias
  df.loc[index,'Structuring of the course'] = rn

  rn = random.randint(1,10)
  if (rn + bias) in range(1, 11):
    rn = rn + bias
  df.loc[index,'Course recommendation based on relevance'] = rn

# %%
df
# Out:
#                 SRN                    Full Name Course     Faculty  \
# 0     PES1UG20CS682                    Rohan T P   AIWR  Divyashree
# 1     PES1UG20CS690          Shivangouda I Patil   AIWR  Divyashree
# 2    PES1UG20CS330   REDDYGARI SURYA TEJA REDDY    AIWR  Divyashree
# 3    PES1UG20CS687                  Satvikkumar    AIWR  Divyashree
# 4     PES1UG21CS818           Manjula Kamannavar   AIWR  Divyashree
# ..              ...                          ...    ...         ...
# 780  PES1UG20CS707                    SUNIDHI N    IPNP     Surabhi
# 781   PES1UG20CS805                    Dhanush V   IPNP     Surabhi
# 782   PES1UG20EC200    SREERAMYA DHARANI PRAGADA   IPNP     Surabhi
# 783   PES1UG21CS813         Hathi Dev Rajeshbhai   IPNP     Surabhi
# 784   PES1UG21CS824        Neeraj Gopalakrishnan   IPNP     Surabhi
#
#      Well versed with the subject  Explains concepts in an understandable way  \
# ...

# %%
#random.randint(1,10)
