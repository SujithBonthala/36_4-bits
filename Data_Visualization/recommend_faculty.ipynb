# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df_score = pd.read_csv('../Dataset/DotSlash_Scores_2.csv')
df_feedback = pd.read_csv('../Dataset/DotSlash_Feedback.csv')

df_concat = pd.concat([df_score, df_feedback], axis=1)

# %%
df_concat
# Out:
#                 SRN                    Full Name Course     Faculty  Score  \
# 0     PES1UG20CS682                    Rohan T P   AIWR  Divyashree     43
# 1     PES1UG20CS690          Shivangouda I Patil   AIWR  Divyashree     65
# 2    PES1UG20CS330   REDDYGARI SURYA TEJA REDDY    AIWR  Divyashree     97
# 3    PES1UG20CS687                  Satvikkumar    AIWR  Divyashree     88
# 4     PES1UG21CS818           Manjula Kamannavar   AIWR  Divyashree     33
# ..              ...                          ...    ...         ...    ...
# 780  PES1UG20CS707                    SUNIDHI N    IPNP     Surabhi     62
# 781   PES1UG20CS805                    Dhanush V   IPNP     Surabhi     62
# 782   PES1UG20EC200    SREERAMYA DHARANI PRAGADA   IPNP     Surabhi     62
# 783   PES1UG21CS813         Hathi Dev Rajeshbhai   IPNP     Surabhi     90
# 784   PES1UG21CS824        Neeraj Gopalakrishnan   IPNP     Surabhi     47
#
# ...

# %%
def fun(df,attr, fac):
  return df[attr].where(df['Faculty'] == fac).mean()

# %%
def recommend(course,df_score_path,df_feedback_path):
    df_score = pd.read_csv(df_score_path)
    df_feedback = pd.read_csv(df_feedback_path)

    #df_concat = pd.concat([df_score, df_feedback], axis=1)
    df_concat = pd.merge(df_score, df_feedback, on=['Course','Faculty','SRN','Full Name'])

    df_concat = df_concat[df_concat['Course']==course]

    fac = df_concat['Faculty'].unique()

    dic = {}

    for name in fac:
        dic[name] = 0

    sum = 0
    for name in fac:
        sum+=fun(df_concat,'Score',name) + fun(df_concat,'Well versed with the subject',name) + fun(df_concat,'Explains concepts in an understandable way',name) + fun(df_concat,'Use of presentations',name) + fun(df_concat,'Solves doubts willingly',name) + fun(df_concat,'Provides support for students going above and beyond',name)
        dic[name] = sum
        sum = 0

    sorted_dict_desc = dict(sorted(dic.items(), key=lambda x: x[1], reverse=True))

    lst = [x for x in sorted_dict_desc.keys()]
    


    return lst

# %%
recommend('AIWR','../Dataset/DotSlash_Scores_2.csv','../Dataset/DotSlash_Feedback.csv')
# Out:
# ['Jayashree', 'Bhaskar', 'Surabhi', 'Divyashree', 'Nage']
